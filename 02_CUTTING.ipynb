# %% [markdown]
# <a href="https://colab.research.google.com/github/joolkas/CV_COURSE/blob/main/02_CUTTING.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow


img = cv2.imread(filename='view.jpg')
#print(img.shape)

height, width, _ = img.shape

w0=width//2-100
w1=width//2+100
h0=height//2-100
h1=height//2+100

reg = img[250:380, 240:330]
img[250:380, 150:240] = reg
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=586x480 at 0x7F6103C3D710>
